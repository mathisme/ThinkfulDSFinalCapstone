# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Getting data

# %%
df = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/TCHOL_J.XPT')

# %% [markdown]
# Taking sequence number, the id number for the observation, and the total cholesterol measured in mg/dl

# %%
df.drop('LBDTCSI',axis=1,inplace=True)
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6738 entries, 0 to 7434
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SEQN    6738 non-null   float64
#  1   LBXTC   6738 non-null   float64
# dtypes: float64(2)
# memory usage: 157.9 KB

# %% [markdown]
# As we are interested in patients 20 or older, we are filtering for age.

# %%
demo = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.XPT')

# %%
demo_merged = demo.merge(df,on='SEQN',how='right')

# %%
demo_merged= demo_merged[demo_merged.RIDAGEYR>=20].copy()
demo_merged.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  93705.0      10.0       2.0       2.0      66.0       NaN       4.0
# 3  93708.0      10.0       2.0       2.0      66.0       NaN       5.0
# 4  93709.0      10.0       2.0       2.0      75.0       NaN       4.0
# 5  93711.0      10.0       2.0       1.0      56.0       NaN       5.0
# 7  93713.0      10.0       2.0       1.0      67.0       NaN       3.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHRMAZ  DMDHSEDZ       WTINT2YR  \
# 0       4.0       2.0       NaN  ...       2.0       NaN    8614.571172
# 3       6.0       2.0       NaN  ...       1.0       1.0   13329.450589
# 4       4.0       1.0       NaN  ...       2.0       NaN   12043.388271
# 5       6.0       2.0       NaN  ...       1.0       3.0   11178.260106
# 7       3.0       1.0       NaN  ...       2.0       NaN  174806.575152
#
#         WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR  LBXTC
# 0    8338.419786      2.0     145.0       3.0       3.0      0.82  157.0
# 3   14372.488765      2.0     138.0       6.0       6.0      1.63  209.0
# 4   12277.556662      1.0     136.0       2.0       2.0      0.41  176.0
# 5   12390.919724      2.0     134.0      15.0      15.0      5.00  238.0
# 7  166841.660681      1.0     140.0       6.0       6.0      2.65  184.0
#
# [5 rows x 47 columns]

# %%
df = demo_merged[['SEQN','LBXTC']].copy()
df.head()
# Out:
#       SEQN  LBXTC
# 0  93705.0  157.0
# 3  93708.0  209.0
# 4  93709.0  176.0
# 5  93711.0  238.0
# 7  93713.0  184.0

# %% [markdown]
# As it is recommended to fast for 9 to 12 hours before getting cholesterol measured, we are filtering for those who fasted at least 9 hours.

# %%
fasting = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/FASTQX_J.XPT')
fasting_merged = df.merge(fasting[fasting.PHAFSTHR >= 9], on='SEQN',how='inner')
df = fasting_merged[['SEQN','LBXTC']].copy()
df.head()
# Out:
#       SEQN  LBXTC
# 0  93708.0  209.0
# 1  93711.0  238.0
# 2  93713.0  184.0
# 3  93715.0  180.0
# 4  93717.0  213.0

# %% [markdown]
# # EDA
#
# ## Distribution of total cholesterol

# %%
df.LBXTC.hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The distribution of total cholesterol looks normal but right skewed.  There are some extreme values above 400. Looking at the distribution when it is log transformed...

# %%
plt.hist(np.log(df.LBXTC))

# %% [markdown]
# # Exploring demographic data in relation to total cholesterol

# %%
demo_merged.corr()['LBXTC'].sort_values()
# Out:
# RIDEXPRG   -0.097854
# SDMVPSU    -0.086771
# DMDHHSZA   -0.043433
# RIDEXMON   -0.041857
# DMDHHSZE   -0.031607
# MIAINTRP   -0.020787
# DMDHRMAZ   -0.020375
# SIAINTRP   -0.017760
# DMDMARTL   -0.016780
# DMDHHSIZ   -0.016450
# DMDFMSIZ   -0.007298
# SDMVSTRA   -0.005437
# SEQN       -0.002398
# INDHHIN2   -0.001406
# DMQADFC     0.000745
# INDFMIN2    0.001280
# FIAINTRP    0.003044
# DMDYRSUS    0.006794
# DMDHHSZB    0.010582
# DMDHREDZ    0.011015
# DMDHRAGZ    0.012087
# RIDRETH1    0.012357
# RIDRETH3    0.019720
# WTMEC2YR    0.019866
# FIALANG     0.020708
# DMDEDUC2    0.024758
# WTINT2YR    0.025337
# DMDCITZN    0.025884
# DMDHRGND    0.026441
# FIAPROXY    0.030869
# SIAPROXY    0.033639
# MIAPROXY    0.035220
# MIALANG     0.037110
# SIALANG     0.038495
# INDFMPIR    0.042540
# DMDBORN4    0.043806
# AIALANGA    0.046639
# RIDAGEYR    0.052039
# DMDHSEDZ    0.056316
# DMQMILIZ    0.064595
# RIAGENDR    0.090433
# LBXTC       1.000000
# SDDSRVYR         NaN
# RIDSTATR         NaN
# RIDAGEMN         NaN
# RIDEXAGM         NaN
# DMDEDUC3         NaN
# Name: LBXTC, dtype: float64

# %% [markdown]
# There is not much correlation between any of the demographic variables and total cholesterol

# %% [markdown]
# ## Gender

# %%
sns.boxplot(x='RIAGENDR', y='LBXTC', data=demo_merged)
# Out:
# <AxesSubplot:xlabel='RIAGENDR', ylabel='LBXTC'>

# %% [markdown]
# The boxplots are relatively similar with respect to gender.

# %% [markdown]
# ## Race

# %%
sns.boxplot(x='RIDRETH3', y='LBXTC', data=demo_merged)
# Out:
# <AxesSubplot:xlabel='RIDRETH3', ylabel='LBXTC'>

# %% [markdown]
# The boxplots again are relatively similar.  However non-Hispanic whites (3.0) have many outliers at a higher total cholesterol level.

# %% [markdown]
# ## Age

# %%
sns.regplot(x='RIDAGEYR',  y='LBXTC', data=demo_merged, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='RIDAGEYR', ylabel='LBXTC'>

# %% [markdown]
# As you can see there is not much of a linear relationship between age and total cholesterol.
#
#
# The demographic data included more variables involving information such as educational level and military status.  These are not going to be explored.  To see a complete list of all the data in the demographics file see https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DEMO_J.htm

# %% [markdown]
# Exploring age of individuals with total cholesterol over 200

# %%
cholage = demo_merged[['RIDAGEYR','LBXTC']][demo_merged.LBXTC > 200].copy()

# %%
cholage['decade']=np.floor(cholage['RIDAGEYR']/10)*10

# %%
sns.countplot(x='decade',data=cholage)
# Out:
# <AxesSubplot:xlabel='decade', ylabel='count'>

# %% [markdown]
# High cholesterol can occur at any age but is most prominent with people in their fifties

# %% [markdown]
# ## BMI and cholesterol and other body measures

# %%
body_df = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BMX_J.XPT')
body_df = body_df.merge(df,on='SEQN',how='right')
body_df.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  93708.0       1.0   53.5    NaN       NaN       NaN      NaN      NaN
# 1  93711.0       1.0   62.1    NaN       NaN       NaN      NaN      NaN
# 2  93713.0       1.0   74.9    NaN       NaN       NaN      NaN      NaN
# 3  93715.0       1.0   65.6    NaN       NaN       NaN      NaN      NaN
# 4  93717.0       1.0   74.4    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT  ...  BMILEG  BMXARML  BMIARML  BMXARMC  BMIARMC  BMXWAIST  \
# 0  150.2    NaN  ...     NaN     30.6      NaN     27.4      NaN      88.2
# 1  170.6    NaN  ...     NaN     37.2      NaN     30.8      NaN      86.6
# 2  178.6    NaN  ...     NaN     41.4      NaN     30.6      NaN      99.7
# 3  170.6    NaN  ...     NaN     39.3      NaN     30.8      NaN      89.7
# 4  174.1    NaN  ...     NaN     41.4      NaN     29.9      NaN      86.2
#
#    BMIWAIST  BMXHIP  BMIHIP  LBXTC
# 0       NaN    90.1     NaN  209.0
# 1       NaN    90.7     NaN  238.0
# 2       NaN    91.0     NaN  184.0
# 3       NaN    93.1     NaN  180.0
# 4       NaN    91.8     NaN  213.0
#
# [5 rows x 22 columns]

# %%
body_df.corr()['LBXTC'].sort_values()
# Out:
# BMXHT      -0.073546
# BMDSTATS   -0.065437
# BMXLEG     -0.058648
# BMXWT      -0.053373
# BMXARML    -0.052694
# BMXHIP     -0.032892
# BMXWAIST   -0.027828
# BMXBMI     -0.025491
# BMXARMC    -0.024070
# SEQN       -0.010141
# BMIWT       0.027600
# BMIHT       0.294650
# LBXTC       1.000000
# BMXRECUM         NaN
# BMIRECUM         NaN
# BMXHEAD          NaN
# BMIHEAD          NaN
# BMILEG           NaN
# BMIARML          NaN
# BMIARMC          NaN
# BMIWAIST         NaN
# BMIHIP           NaN
# Name: LBXTC, dtype: float64

# %% [markdown]
# As with demographic data there appears to be no strong correlation with body measures and total cholesterol.

# %% [markdown]
# ##  Compairing height, weight, bmi, and total cholesterol

# %%
sns.regplot(x='BMXWT',  y='LBXTC', data=body_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='BMXWT', ylabel='LBXTC'>

# %% [markdown]
# As can be seen there is not much correlation between weight and cholesterol level.

# %%
sns.regplot(x='BMXHT',  y='LBXTC', data=body_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='BMXHT', ylabel='LBXTC'>

# %% [markdown]
# As height increases, total cholesterol slightly decreases.

# %%
sns.regplot(x='BMXBMI',  y='LBXTC', data=body_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='BMXBMI', ylabel='LBXTC'>

# %% [markdown]
# There doesn't appear to be much correlation between body mass index and total cholesterol.  All three replots do show outliers.

# %%
sns.regplot(x='BMXWAIST',  y='LBXTC', data=body_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='BMXWAIST', ylabel='LBXTC'>

# %% [markdown]
# Again there isn't much correlation between waist circumference and total cholesterol level.

# %% [markdown]
# ## Examining blood pressure and pulse with respect to total cholesterol

# %%
bp_df = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPX_J.XPT')
bp_df = bp_df.merge(df,on='SEQN',how='right')
bp_df.head()
# Out:
#       SEQN  PEASCCT1  BPXCHR  BPAARM  BPACSZ  BPXPLS  BPXPULS  BPXPTY  BPXML1  \
# 0  93708.0       NaN     NaN     1.0     3.0    68.0      1.0     1.0   170.0
# 1  93711.0       NaN     NaN     1.0     4.0    62.0      1.0     1.0   130.0
# 2  93713.0       NaN     NaN     1.0     4.0    90.0      1.0     1.0   130.0
# 3  93715.0       NaN     NaN     1.0     3.0    66.0      1.0     1.0   150.0
# 4  93717.0       NaN     NaN     1.0     3.0    60.0      1.0     1.0   140.0
#
#    BPXSY1  ...  BPXSY2  BPXDI2  BPAEN2  BPXSY3  BPXDI3  BPAEN3  BPXSY4  \
# 0     NaN  ...   138.0    78.0     2.0   144.0    76.0     2.0   144.0
# 1   108.0  ...    94.0    68.0     2.0   102.0    64.0     2.0     NaN
# 2   104.0  ...   104.0    74.0     2.0   106.0    72.0     2.0     NaN
# 3   112.0  ...   112.0    58.0     2.0   118.0    60.0     2.0     NaN
# 4   116.0  ...   124.0    66.0     2.0   116.0    68.0     1.0     NaN
#
#    BPXDI4  BPAEN4  LBXTC
# 0    74.0     2.0  209.0
# 1     NaN     NaN  238.0
# 2     NaN     NaN  184.0
# 3     NaN     NaN  180.0
# 4     NaN     NaN  213.0
#
# [5 rows x 22 columns]

# %%
bp_df.corr()['LBXTC'].sort_values()
# Out:
# BPAEN4     -0.091418
# PEASCCT1   -0.084177
# BPXPULS    -0.070839
# BPXPTY     -0.025535
# BPAEN3     -0.018620
# BPACSZ     -0.017007
# BPAEN2     -0.011996
# SEQN       -0.010141
# BPAARM     -0.003210
# BPXPLS      0.031864
# BPXSY4      0.101131
# BPXML1      0.105191
# BPXSY3      0.116763
# BPXSY2      0.120595
# BPXSY1      0.126626
# BPXDI1      0.144354
# BPXDI3      0.147145
# BPXDI2      0.148131
# BPXDI4      0.189845
# LBXTC       1.000000
# BPXCHR           NaN
# BPAEN1           NaN
# Name: LBXTC, dtype: float64

# %% [markdown]
# No large correlation can be seen
#
# For systolic and diastolic readings there were up to 4 readings taken.  I am going to average all 4 into 1 systolic and 1 diastolic reading.

# %%
bp_df['Systolic'] = bp_df[['BPXSY1','BPXSY2','BPXSY3','BPXSY4']].mean(axis=1)
bp_df["Diastolic"] = bp_df[['BPXDI1','BPXDI2','BPXDI3','BPXDI4']].mean(axis=1)

# %%
sns.regplot(x='Systolic',  y='LBXTC', data=bp_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Systolic', ylabel='LBXTC'>

# %% [markdown]
# As systolic levels rise, total cholesterol slightly rises.

# %%
sns.regplot(x='Diastolic',  y='LBXTC', data=bp_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Diastolic', ylabel='LBXTC'>

# %% [markdown]
# The same can be seen with diastolic levels, as the levels rise, total cholesterol slightly rises.  Looking at the distributions of systolic and diastolic variables...

# %%
bp_df.Systolic.hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The distribution is right skewed with some extreme outliers above 225.

# %%
bp_df.Diastolic.hist(bins=25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The diastolic distribution appears more normal.  Values of 0 are more than likely missing values.

# %% [markdown]
# Looking at pulse...

# %%
sns.regplot(x='BPXPLS',  y='LBXTC', data=bp_df, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='BPXPLS', ylabel='LBXTC'>

# %% [markdown]
# There doesn't appear to be much relation between resting pulse and total cholesterol level.  I can do a hypothesis test here to look at the difference of means.
# Looking at wether or not the pulse is irregular.

# %%
sns.boxplot(x='BPXPULS',  y='LBXTC', data=bp_df)
# Out:
# <AxesSubplot:xlabel='BPXPULS', ylabel='LBXTC'>

# %% [markdown]
# It is interesting that those with a regular pulse (1) have slightly higher total cholesterol levels than those with an irregular pulse.  Maybe those with an irregular pulse are on medication that also controls cholesterol.

# %% [markdown]
# ## Dietary data -- diet habits

# %%
diet1 = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DR1TOT_J.XPT')
diet = diet1.merge(df,on='SEQN',how='right')

# %%
(diet.isnull().sum()/diet.shape[0]).sort_values(ascending=False)
# Out:
# DRQSDT5     1.000000
# DRD370PQ    0.999253
# DRQSDT8     0.999253
# DRQSDT6     0.999253
# DRD370JQ    0.998880
#               ...
# DRD360      0.073189
# SEQN        0.000000
# WTDRD1      0.000000
# DR1DRSTZ    0.000000
# LBXTC       0.000000
# Length: 169, dtype: float64

# %% [markdown]
# For those that do not use table salt, the 'how often is salt used' was set to 0.

# %%
diet.loc[diet.DBQ095Z==4,'DBD100']=0

# %%
sns.boxplot(x='DBD100', y='LBXTC', data=diet)
# Out:
# <AxesSubplot:xlabel='DBD100', ylabel='LBXTC'>

# %% [markdown]
# The medians of cholesterol are similar no matter how often salt is used.  However the largest outliers are with those that use salt very often. Looking at those who know their salt intake

# %% [markdown]
# Looking at how often salt is used in preparing food.

# %%
# need to do salt preparation questions

sns.boxplot(x='DRQSPREP', y='LBXTC', data=diet)
# Out:
# <AxesSubplot:xlabel='DRQSPREP', ylabel='LBXTC'>

# %% [markdown]
# The medians slightly increase when salt is used in preparing food.

# %%
sns.boxplot(x='DRQSDIET', y='LBXTC', data=diet)
# Out:
# <AxesSubplot:xlabel='DRQSDIET', ylabel='LBXTC'>

# %% [markdown]
# Again the boxplots are similar, however more that are not on any special diet have high cholesterol.

# %% [markdown]
# ## Dietary Data total nutrition

# %% [markdown]
# First we will look at the nutrition variables without any transformation.  Later we will use the variable DR1_300, compared amount of food eaten to usual, to transform into estimated average values and regraph all.

# %%
nutrition_variables = {
'variable':['DR1TKCAL','DR1TPROT','DR1TCARB','DR1TSUGR','DR1TFIBE','DR1TTFAT',
'DR1TSFAT','DR1TMFAT','DR1TPFAT','DR1TCHOL','DR1TSODI'],
'description':['Calories','Protein','Carbohydrates','Total sugars','Dietary fiber','Total fat',
'Total saturated fat','Total monounsaturated fatty acids','Total polyunsaturated fatty acid','Cholesterol','Sodium']
}

# %%
n = len(nutrition_variables['variable'])

fig, axs = plt.subplots(n,1,figsize=[4,40])
for i in range(n):
    sns.regplot(x=nutrition_variables['variable'][i],  y='LBXTC', ax=axs[i], data=diet, scatter_kws={"color": "blue"}, 
                line_kws={"color": "red"})
    axs[i].set_xlabel(nutrition_variables['description'][i])
    axs[i].set_ylabel('Total Cholestrol')

# %% [markdown]
# There doesn't seem to be much correlation between any nutrition value and total cholesterol.

# %%
diet[nutrition_variables['variable']+['LBXTC']].corr()['LBXTC'].sort_values()
# Out:
# DR1TPFAT   -0.053120
# DR1TTFAT   -0.047159
# DR1TMFAT   -0.046865
# DR1TSODI   -0.041433
# DR1TCARB   -0.041294
# DR1TKCAL   -0.039907
# DR1TSFAT   -0.034543
# DR1TSUGR   -0.023859
# DR1TPROT   -0.017088
# DR1TFIBE   -0.002102
# DR1TCHOL    0.001149
# LBXTC       1.000000
# Name: LBXTC, dtype: float64

# %% [markdown]
# Getting the diet variables for which diet.DR1_300, how does the amount of food you ate compare to normal, is 1, much more than usual, 2, usual, or 3, much less than usual

# %%
diet_transformed = diet[diet.DR1_300<=3].copy()

# %% [markdown]
# transforming the DR1_300 values by subtracting 2 to get -1, 0, 1 as these will be used for exponents

# %%
diet_transformed['DR1_300'] = diet_transformed.DR1_300-2

# %% [markdown]
# need to explain what you did here

# %%
multipliers = [1,2,4]
n = len(nutrition_variables['variable'])
fig, axs = plt.subplots(n,3,figsize=[12,40])
for k in range(3):
    for i in range(n):
        variable = nutrition_variables['variable'][i]
        name = '{}_transformed'.format(variable)
        diet_transformed[name] = diet_transformed[variable]*(multipliers[k]**diet_transformed['DR1_300'])
        sns.regplot(x=name, y='LBXTC', ax=axs[i,k], data=diet_transformed, scatter_kws={"color": "blue"}, 
                line_kws={"color": "red"})

# %% [markdown]
# There doesn't appear to be much change with the transformation.  I may want to just read the variables as well as the DR1_300 variable

# %%
diet_transformed2 = diet[diet.DR1_300<=3].copy()

# %%
n = len(nutrition_variables['variable'])
fig, axs = plt.subplots(n,3,figsize=[12,40])
for i in range(1,4):
    diet2 = diet_transformed2[diet_transformed2.DR1_300==i]
    for j in range(n):
        sns.regplot(x=nutrition_variables['variable'][j], y='LBXTC', ax=axs[j,i-1], data=diet2, scatter_kws={"color": "blue"}, 
                line_kws={"color": "red"})

# %%
n = len(nutrition_variables['variable'])
fig, axs = plt.subplots(n,3,figsize=[12,40])
for i in range(1,4):
    diet2 = diet_transformed2[diet_transformed2.DR1_300==i]
    for j in range(n):
        sns.histplot(x=nutrition_variables['variable'][j],ax=axs[j,i-1], data=diet2, bins=25)

# %% [markdown]
# ## nutrients

# %% [markdown]
# Vitamin D, calcium, iron, and potassium are the only micronutrients required to be on the food label.
# https://medlineplus.gov/ency/article/002459.htm

# %%
nutrient_variables = {
    'variable':['DR1TVD','DR1TCALC','DR1TIRON','DR1TPOTA'],
    'description':['Vitamin D','Calcium','Iron','Potassium']
}

# %%
fig, axs = plt.subplots(n,1,figsize=[4,40])
for i in range(n):
    sns.regplot(x=nutrient_variables['variable'][i],  y='LBXTC', ax=axs[i], data=diet, scatter_kws={"color": "blue"}, 
                line_kws={"color": "red"})
    axs[i].set_xlabel(nutrient_variables['description'][i])
    axs[i].set_ylabel('Total Cholestrol')

# %%
n = len(nutrient_variables['variable'])
fig, axs = plt.subplots(n,3,figsize=[12,40])
for i in range(1,4):
    diet2 = diet_transformed2[diet_transformed2.DR1_300==i]
    for j in range(n):
        sns.regplot(x=nutrient_variables['variable'][j], y='LBXTC', ax=axs[j,i-1], data=diet2, scatter_kws={"color": "blue"}, 
                line_kws={"color": "red"})

# %% [markdown]
# There is a definite change depending if the amount consumed is less than normal, normal, or more than normal.  May want to use 2, 1, 0.5 multiplier on all nutrients depending on their consumption amount.
# Or do both, 1 with multiplier, 1 without but with the added variable.

# %% [markdown]
# ## Alcohol use

# %%
alcohol = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/ALQ_J.XPT')
alcohol_merge = alcohol.merge(df,on='SEQN',how='right')

# %% [markdown]
# alcohol.ALQ121 asks how often you have drinks in the past 12 months

# %%
sns.boxplot(x='ALQ121', y='LBXTC', data=alcohol_merge)
# Out:
# <AxesSubplot:xlabel='ALQ121', ylabel='LBXTC'>

# %% [markdown]
# ALQ130 asks on days you drink, how many drinks did you have.
#
# I want to use these two questions to approximate the number of alcoholic drinks per year then use a scatterplot comparing that to total cholesterol level.

# %%
alcohol_merge.ALQ121.unique()
# Out:
# array([           nan, 5.00000000e+00, 6.00000000e+00, 5.39760535e-79,
#        1.00000000e+00, 7.00000000e+00, 9.00000000e+00, 1.00000000e+01,
#        3.00000000e+00, 2.00000000e+00, 8.00000000e+00, 4.00000000e+00])

# %% [markdown]
# I'm assuming the 5 e -79 means 0

# %%
def alcdays(x):
    if np.isnan(x):
        return x
    dic = {0:0,1:365,2:300,3:3.5*52,4:104,5:52,6:2.5*12,7:12,8:9,9:4.5,10:1.5,77:np.nan,99:np.nan}
    if x not in dic.keys():
        return 0
    return dic[x]

# %%
alcohol_merge['num_drinks']=(alcohol_merge.ALQ121.apply(alcdays))*(alcohol_merge.ALQ130)

# %%
sns.regplot(x='num_drinks',  y='LBXTC', data=alcohol_merge, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='num_drinks', ylabel='LBXTC'>

# %% [markdown]
# For those that drink large amounts, as the number of drinks goes up the total cholesterol goes up.

# %% [markdown]
# ## Blood pressure and cholesterol questionaire data

# %%
bpc = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/BPQ_J.XPT')
bpc_merged = bpc.merge(df,on='SEQN',how='right')

# %% [markdown]
# ### BPQ020 -- Ever told you have high blood pressure

# %%
sns.boxplot(x='BPQ020', y='LBXTC', data=bpc_merged)
# Out:
# <AxesSubplot:xlabel='BPQ020', ylabel='LBXTC'>

# %% [markdown]
# 1 represents yes, 2 represents no, and 9 represents don't know.  For those that have been told they have high blood pressure there are more outliers with higher levels of cholesterol.

# %% [markdown]
# Those that have not been told they have high blood pressure didn't have to ask questions regarding taking medication.  Therefore I will fill in those missing values with no, never been told to take medication.

# %%
bpc_merged.loc[bpc_merged.BPQ020==2,'BPQ040A']=2

# %% [markdown]
# BPQ040A asks if you have ever been told to take medication for high blood pressure while BPQ050A asks are you currently taking medication for high blood pressure.  As BPQ050A is skipped if the response for BPQ040A is no, I'm filling in those missing values with the value for no, 2.

# %%
bpc_merged.loc[bpc_merged.BPQ040A==2,'BPQ050A']=2

# %%
sns.boxplot(x='BPQ050A', y='LBXTC', data=bpc_merged)
# Out:
# <AxesSubplot:xlabel='BPQ050A', ylabel='LBXTC'>

# %% [markdown]
# The medians are about the same, however many with high cholesterol are not on blood pressure medicine and there are some with extremely high cholesterol that are on blood pressure medication.

# %% [markdown]
# ## BPQ080 -- told you have high cholesterol
#
# Note to self, do I want to include those on medication for cholesterol or been told you have high cholesterol?

# %%
sns.boxplot(x='BPQ080', y='LBXTC', data=bpc_merged)
# Out:
# <AxesSubplot:xlabel='BPQ080', ylabel='LBXTC'>

# %% [markdown]
# Those that have been told they have high cholesterol have many more outliers with high cholesterol.

# %% [markdown]
# ### BPQ100D -- now taking prescription medication for cholesterol.
#
# For those that have not been told to take medication, I first am going to make sure their value for the variable is 2, not taking medication.

# %%
bpc_merged.loc[bpc_merged.BPQ090D==2,'BPQ100D']=2

# %%
sns.boxplot(x='BPQ100D', y='LBXTC', data=bpc_merged)
# Out:
# <AxesSubplot:xlabel='BPQ100D', ylabel='LBXTC'>

# %% [markdown]
# The median for cholesterol levels is higher for those not on cholesterol meds than those on cholesterol meds well as those not on meds have many more outliers with higher levels of total cholesterol.

# %% [markdown]
# ## Cardiovascular health
# These are questions regarding pain in chest and arms and shortness of breath.  Now I haven't decided if I want to include these as I'm not sure if a fitness or health app would ask about pain or shortness of breath.

# %%
cardio_health = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/CDQ_J.XPT')
ch_merged = cardio_health.merge(df,on='SEQN',how='right')

# %%
sns.boxplot(x='CDQ001', y='LBXTC', data=ch_merged)
# Out:
# <AxesSubplot:xlabel='CDQ001', ylabel='LBXTC'>

# %% [markdown]
# Those that have had pain or discomfort have larger outliers with higher levels of total cholesterol but there is not much difference.

# %%
sns.boxplot(x='CDQ010', y='LBXTC', data=ch_merged)
# Out:
# <AxesSubplot:xlabel='CDQ010', ylabel='LBXTC'>

# %% [markdown]
# Again, with shortness of breath, not much difference.  Those that respond as don't know have a higher total cholesterol box.

# %% [markdown]
# ## General health status

# %%
health_status = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/HSQ_J.XPT')
hs_merged = health_status.merge(df,on='SEQN',how='right')

# %%
sns.boxplot(x='HSD010', y='LBXTC', data=hs_merged)
# Out:
# <AxesSubplot:xlabel='HSD010', ylabel='LBXTC'>

# %% [markdown]
# Not much difference.  Those with a health status of good, 3, seems to have the most outliers with high cholesterol.

# %% [markdown]
# ## Diabetes

# %%
diabetes = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DIQ_J.XPT')
diabetes_merged = diabetes.merge(df,on='SEQN',how='right')

# %%
sns.boxplot(x='DIQ010', y='LBXTC', data=diabetes_merged)
# Out:
# <AxesSubplot:xlabel='DIQ010', ylabel='LBXTC'>

# %% [markdown]
# Those told they don't have diabetes, 2, on average have higher cholesterol than those with diabetes, 1.  It would be interesting to investigate whether those with diabetes are on medication for cholesterol.
#
# There are many more variables in the diabetes dataset, to take a look at what it all includes, see https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DIQ_J.htm
#
# I am skipping them

# %% [markdown]
# ## Diet behavior and nutrition

# %%
diet_behavior = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DBQ_J.XPT')
db_merged = diet_behavior.merge(df,on='SEQN',how='right')

# %% [markdown]
# ## Question: how healthy is diet?
#
# I'm not sure if I want to include this as a health app may be tracking diet

# %%
sns.boxplot(x='DBQ700', y='LBXTC', data=db_merged)
# Out:
# <AxesSubplot:xlabel='DBQ700', ylabel='LBXTC'>

# %% [markdown]
# As can be seen there isn't much difference.
#
# There are many more variables I am not going to explore.  Information on the variables can be found here: https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DBQ_J.htm

# %% [markdown]
# ## Kidney conditions

# %%
kidney = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/KIQ_U_J.XPT')
kidney_merged = kidney.merge(df,on='SEQN',how='right')

# %%
kidney_merged.corr()['LBXTC'].sort_values()
# Out:
# KIQ010   -0.088572
# KIQ042   -0.063581
# KIQ430   -0.058850
# KIQ450   -0.057710
# KIQ470   -0.043030
# KIQ480   -0.022597
# KIQ052   -0.020113
# KIQ025   -0.018449
# KIQ044   -0.017291
# KIQ029   -0.015782
# KIQ046   -0.010432
# SEQN     -0.010141
# KIQ050   -0.008313
# KIQ005    0.016751
# KIQ022    0.028298
# KIQ026    0.098902
# LBXTC     1.000000
# Name: LBXTC, dtype: float64

# %% [markdown]
# There isn't much correlation between kidney conditions and cholesterol.

# %%
sns.boxplot(x='KIQ022', y='LBXTC', data=kidney_merged)
# Out:
# <AxesSubplot:xlabel='KIQ022', ylabel='LBXTC'>

# %% [markdown]
# Those without kidney problems, 2, have slightly higher cholesterol, on average, than those with weak or failing kidneys

# %% [markdown]
# ## Other medical conditions

# %%
mc = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/MCQ_J.XPT')
mc_merged = mc.merge(df,on='SEQN',how='right')
# look at thyroid conditions

# %% [markdown]
# ### Thyroid Conditions
#
# MCQ160m asks if you have ever been told you have a thryoid condition
# MCQ170m asks if you still have a thryoid condition.
#
# To reduce missing values, those that answered no to MCQ160m, I am replacing the value of MCQ170m with 2, which means no.
# I am also replacing the don't know or refused values of MCQ170 m with np.nan

# %%
mc_merged.columns
# Out:
# Index(['SEQN', 'MCQ010', 'MCQ025', 'MCQ035', 'MCQ040', 'MCQ050', 'AGQ030',
#        'MCQ053', 'MCQ080', 'MCQ092', 'MCD093', 'MCQ149', 'MCQ151', 'RHD018',
#        'MCQ160A', 'MCD180A', 'MCQ195', 'MCQ160N', 'MCD180N', 'MCQ160B',
#        'MCD180B', 'MCQ160C', 'MCD180C', 'MCQ160D', 'MCD180D', 'MCQ160E',
#        'MCD180E', 'MCQ160F', 'MCD180F', 'MCQ160M', 'MCQ170M', 'MCD180M',
#        'MCQ160G', 'MCD180G', 'MCQ160K', 'MCQ170K', 'MCD180K', 'MCQ160O',
#        'MCQ160L', 'MCQ170L', 'MCD180L', 'MCQ500', 'MCQ510A', 'MCQ510B',
#        'MCQ510C', 'MCQ510D', 'MCQ510E', 'MCQ510F', 'MCQ520', 'MCQ530',
#        'MCQ540', 'MCQ550', 'MCQ560', 'MCQ570', 'MCQ203', 'MCQ206', 'MCQ220',
#        'MCQ230A', 'MCD240A', 'MCQ230B', 'MCD240B', 'MCQ230C', 'MCD240C',
#        'MCQ230D', 'MCQ300B', 'MCQ300C', 'MCQ300A', 'MCQ366A', 'MCQ366B',
#        'MCQ366C', 'MCQ366D', 'MCQ371A', 'MCQ371B', 'MCQ371C', 'MCQ371D',
#        'OSQ230', 'LBXTC'],
#       dtype='object')

# %%
mc_merged.loc[mc_merged.MCQ160M==2,'MCQ170M']=2
mc_merged.loc[mc_merged.MCQ170M==7,'MCQ170M']=np.nan
mc_merged.loc[mc_merged.MCQ170M==9,'MCQ170M']=np.nan

# %%
# need to do graph

# %% [markdown]
# # Smoking

# %%
tobacco = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/SMQRTU_J.XPT')
tb_merged = tobacco.merge(df,on='SEQN',how='right')

# %%
# just interested in the one variable have you smoked in the last 5 days
sns.boxplot(x='SMQ681', y='LBXTC', data=tb_merged)
# Out:
# <AxesSubplot:xlabel='SMQ681', ylabel='LBXTC'>

# %% [markdown]
# Medians are the same but for those that have smoked in the last 5 days, the outliers are higher.

# %% [markdown]
# # Physical activity

# %%
activity = pd.read_sas('https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/PAQ_J.XPT')
activity_merged = activity.merge(df,on='SEQN',how='right')

# %% [markdown]
# I'm just looking at activity for recreational activities as people might not wear their fitness trackers to work.

# %%
# for those that don't do vigorous recreational activity, I'm setting the day values and minute values to 0.
activity_merged.loc[activity_merged.PAQ650==2,'PAQ655']=0
activity_merged.loc[activity_merged.PAQ650==2,'PAD660']=0
# same for moderate activity
activity_merged.loc[activity_merged.PAQ665==2,'PAQ670']=0
activity_merged.loc[activity_merged.PAQ665==2,'PAD675']=0
# for those that do not know how many days or minutes, I'm setting it to nan
activity_merged.PAQ655.replace({99:np.nan},inplace=True)
activity_merged.PAD660.replace({9999:np.nan},inplace=True)
activity_merged.PAQ670.replace({99:np.nan},inplace=True)
activity_merged.PAD675.replace({9999:np.nan},inplace=True)

# %%
activity_merged['Exercise_total']=activity_merged.PAQ655*activity_merged.PAD660*8 + 4*activity_merged.PAQ670*activity_merged.PAD675

# %%
sns.regplot(x='Exercise_total',  y='LBXTC', data=activity_merged, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Exercise_total', ylabel='LBXTC'>

# %% [markdown]
# As seen, there is a slight decrease in total cholesterol when the person does more physical activity
